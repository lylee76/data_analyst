# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
#                                     Pandas
# ==========================================================================================================================
# Pandas is a Python library used for data manipulation and analysis. Pandas provides a convenient way to analyze and clean data.
#
# The Pandas library introduces two new data structures to Python - Series and DataFrame, both of which are built on top of NumPy.
#
# What is Pandas Used for?
# Pandas is a powerful library generally used for:
#
# Data Cleaning
# Data Transformation
# Data Analysis
# Machine Learning
# Data Visualization
#
# import pandas as pd----for importing pandas

# %% [markdown]
# -----------------------
# Pandas Series:
# A Pandas Series is a one-dimensional labeled array-like object that can hold data of any type.
#
# A Pandas Series can be thought of as a column in a spreadsheet or a single column of a DataFrame. It consists of two main components: the labels and the data.
#
# For example,
#
# 0    'John'
# 1    30
# 2    6.2
# 3    False
# dtype: object
#
#  Pandas Series can store elements of different data types. It uses a concept called dtype (data type) to manage and represent the underlying data in a Series.
#
# By default, Pandas internally represents the Series of different datatypes using the object data type, a general-purpose data type that can hold any text or numeric data type(strings, integers, booleans, etc).

# %% [markdown]
# ---------------------------------------------------------------
# Syntax of pandas series:
#
# import pandas as pd
#
# series = pd.Series(data, index=optional_index)
# optional index = either in the tuple , list.

# %%
import pandas as pd

list1 = [1,2,3,"string"]
list2 = [4,5,6,"abc"]
list3 = list1 + list2
print(list3)
# new_variable = pd.Series(list)
series = pd.Series(list3, index=['a','b','c','d','e','f','g','h'])
print(series)
# Out:
# [1, 2, 3, 'string', 4, 5, 6, 'abc']
# a         1
# b         2
# c         3
# d    string
# e         4
# f         5
# g         6
# h       abc
# dtype: object

# %% [markdown]
# So, the most used attributes of pd.Series are:
# values, index, dtype, shape, ndim, size, name, is_unique, is_monotonic_increasing, is_monotonic_decreasing, empty, T, nbytes, hasnans

# %%
#creating a pandas series:
import pandas as pd

# create a list
data = [10, 20, 30, 40, 50, 60,70]

# create a series from the list
my_series = pd.Series(data)

print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
import pandas as pd

# create a dictionary
grades = {"Semester1":['John', 'Alice', 'Bob'], "Semester2": 3.28, "Semester3": 3.75}
#grades = [3.14, 2.98, 3.04]
# create a series from the dictionary
my_series = pd.Series(grades)

# display the series
print(my_series)
# Out:
# Semester1    [John, Alice, Bob]
# Semester2                  3.28
# Semester3                  3.75
# dtype: object

# %% [markdown]
# s = pd.Series([10, 20, 30])
#
# | **Attribute**             | **What it does**                                | **Example Output**                     |
# | ------------------------- | ----------------------------------------------- | -------------------------------------- |
# | `values`                  | Returns the data as a **NumPy array**           | `[10 20 30]`                           |
# | `index`                   | Returns the **index labels**                    | `Index(['a','b','c'], dtype='object')` |
# | `dtype`                   | Data type of the Series elements                | `int64`, `float64`, `object`, etc.     |
# | `shape`                   | Returns a tuple showing the shape (#elements,)  | `(3,)`                                 |
# | `ndim`                    | Number of dimensions (always `1` for Series)    | `1`                                    |
# | `size`                    | Number of elements in the Series                | `3`                                    |
# | `name`                    | Name of the Series (can set or get)             | `"my_data"`                            |
# | `is_unique`               | `True` if all values are unique, else `False`   | `False`                                |
# | `is_monotonic_increasing` | `True` if values are sorted in increasing order | `True` / `False`                       |
# | `is_monotonic_decreasing` | `True` if values are sorted in decreasing order | `True` / `False`                       |
# | `empty`                   | `True` if Series has no elements                | `False`                                |
# | `T`                       | Transpose (for Series, same as itself)          | Same as Series                         |
# | `nbytes`                  | Number of **bytes** consumed by the Series data | e.g. `24`                              |
# | `hasnans`                 | `True` if Series contains any `NaN` values      | `True` / `False`                       |

# %% [markdown]
# ---------------------Labels in Pandas Series_------------------------------------
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 1.The labels in the Pandas Series are index numbers by default.
# 2.The index number in series starts from 0.
# 3.lets create a pandas series:
#
#
#
#
#
# Create Indexes in Pandas
# Pandas offers several ways to create indexes. Some common methods are as follows:
#
# a.Default Index
# b.Setting Index
# c.Creating a Range Index
#
#
#
#
# b.Setting Index:
# ------------------------We can set an existing column as the index using the set_index() method
#
# like create a ---------
# import pandas as pd
#
# # create dataframe
# data = {'Name': ['John', 'Alice', 'Bob'],
#         'Age': [25, 28, 32],
#         'City': ['New York', 'London', 'Paris']}
#
# df = pd.DataFrame(data)
#
# # set the 'Name' column as index
# df.set_index('Name', inplace=True)
#
# print(df)
#
#
#
# c.Creating a range index:
# import pandas as pd
#
# # create dataframe
# data = {'Name': ['John', 'Alice', 'Bob'],
#         'Age': [25, 28, 32],
#         'City': ['New York', 'London', 'Paris']
#         }
#
# df = pd.DataFrame(data)
#
# # create a range index
# df = pd.DataFrame(data, index=pd.RangeIndex(5, 8, name='Index'))
#
# print(df)

# %%
import numpy as np
data = {'Name': ['John', 'Alice', 'Bob'],
        'Age': [25, 28, 32],
        'City': ['New York', 'London', 'Paris']}

# data = [['John', 'Alice', 'Bob'],
#         [25, 28, 32],
#         ['New York', 'London', 'Paris']]

# df = pd.DataFrame(data)
df = pd.DataFrame(data)

df2 = pd.Series(data)

# set the 'Name' column as index
#df.set_index('Name', inplace=True)

print(df)
print()
print()
print(df2)
# Out:
#     Name  Age      City
# 0   John   25  New York
# 1  Alice   28    London
# 2    Bob   32     Paris
#
#
# Name           [John, Alice, Bob]
# Age                  [25, 28, 32]
# City    [New York, London, Paris]
# dtype: object

# %%
# create dataframe
data = {'Name': ['John', 'Alice', 'Bob'],
        'Age': [25, 28, 32],
        'City': ['New York', 'London', 'Paris']}

df = pd.DataFrame(data)

# set the 'Name' column as index
df.set_index('Name', inplace=True)

print(df)

# create dataframe
data = {'Name': ['John', 'Alice', 'Bob'],
        'Age': [25, 28, 32],
        'City': ['New York', 'London', 'Paris']
        }

# df = pd.DataFrame(data)

# create a range index
df = pd.DataFrame(data, index=pd.RangeIndex(5, 8, name='Index'))

print(df)
# Out:
#        Age      City
# Name
# John    25  New York
# Alice   28    London
# Bob     32     Paris
#         Name  Age      City
# Index
# 5       John   25  New York
# 6      Alice   28    London
# 7        Bob   32     Paris

# %% [markdown]
# -----------------------------------------------------------------------
# What we required the most is the table data which looks clear , sweet and precise
#
# So , we had Pandas DataFrame...
# ---------------------------------------------------------------------------------------
#                                    Pandas Dataframe
#
# A DataFrame is like a table where the data is organized in rows and columns. It is a two-dimensional data structure like a two-dimensional array. For example,
#
#      Country      Capital      Population
#
# 0    Canada       Ottawa       37742154
#
# 1    Australia    Canberra     25499884
#
# 2    UK           London       67886011
#
# 3    Brazil       Brasília     212559417
#
#
# Here,
#
# Country, Capital and Population are the column names.
# Each row represents a record, with the index value on the left. The index values are auto-assigned starting from 0.
# Each column contains data of the same type. For instance, Country and Capital contain strings, and Population contains integers.
# The DataFrame is similar to a table in a SQL database, or a spreadsheet in Excel. It is designed to manage ordered and unordered datasets in Python.

# %% [markdown]
# Create a Pandas DataFrame
# We can create a Pandas DataFrame in the following ways:
#
# Using Python Dictionary
# Using Python List
# From a File
# Creating an Empty DataFrame

# %%
#using Dictionary
import pandas as pd

# create a dictionary
data = {'Name': ['John', 'Alice', 'Bob'],
       'Age': [25, 30, 35],
       'City': ['New York', 'London', 'Paris']}

# create a dataframe from the dictionary
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age      City
# 0   John   25  New York
# 1  Alice   30    London
# 2    Bob   35     Paris

# %%
#create a pandas dataframe  from the list:

import pandas as pd

# create a two-dimensional list
data = [['John', 25, 'New York'],
       ['Alice', 30, 'London'],
       ['Bob', 35, 'Paris']]

# create a DataFrame from the list
df = pd.DataFrame(data, columns=['Name', 'Age', 'City'])

print(df)
# Out:
#     Name  Age      City
# 0   John   25  New York
# 1  Alice   30    London
# 2    Bob   35     Paris

# %%
data = [1,2,3,4,5,6]
df = pd.DataFrame(data, index=["a","b","c","d","e","f"], columns=["Number"])
print(df)
# Out:
#    Number
# a       1
# b       2
# c       3
# d       4
# e       5
# f       6

# %% [markdown]
# Write a Python program using Pandas to create a table that contains the following columns and data:
#
# Employee Name: John, Kate, Leo
#
# Department: IT, HR, Sales
#
# Salary: 50000, 55000, 60000

# %% [markdown]
# Using a list of lists, create a Pandas DataFrame for the following data and set the column name as "Employee", "Department", "Salary"

# %% [markdown]
# ###########################################################################-----------------
# SO now lets import a data from kaggle and lets get dive into the world of pandas data analysis>
