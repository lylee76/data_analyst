# %%
import pandas as pd


df = pd.read_csv("sampledata.csv")
df
# Out:
#    Column1  Column2 Column3  Column4  Column5
# 0        1       78       A    -0.61    False
# 1        2       94       C    -0.90     True
# 2        3       59       B    -0.17     True
# 3        4       32       C    -2.74    False
# 4        5       65       B     1.14     True
# 5        6       94       D    -0.76     True
# 6        7       21       A    -1.48    False
# 7        8       74       D    -0.37     True
# 8        9       37       D     1.00    False
# 9       10       27       A    -0.27     True

# %% [markdown]
# #pandas dataframe manipulation:
# DataFrame manipulation in Pandas involves editing and modifying existing DataFrames. Some common DataFrame manipulation operations are:
#
# 1.Adding rows/columns
# 2.Removing rows/columns
# 3.Renaming rows/columns

# %% [markdown]
# Above table contain the Nan columns , no value so we do:

# %%
df.columns
# Out:
# Index(['Column1', 'Column2', 'Column3', 'Column4', 'Column5'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Column1  10 non-null     int64
#  1   Column2  10 non-null     int64
#  2   Column3  10 non-null     object
#  3   Column4  10 non-null     float64
#  4   Column5  10 non-null     bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 462.0+ bytes

# %%
df.shape
# Out:
# (10, 5)

# %%
df.describe() # Statistical SUmmary
# Out:
#         Column1   Column2    Column4
# count  10.00000  10.00000  10.000000
# mean    5.50000  58.10000  -0.516000
# std     3.02765  27.37578   1.122172
# min     1.00000  21.00000  -2.740000
# 25%     3.25000  33.25000  -0.865000
# 50%     5.50000  62.00000  -0.490000
# 75%     7.75000  77.00000  -0.195000
# max    10.00000  94.00000   1.140000

# %%
# 1.removing columns:
df = df.drop(columns=["Column4"]) # To drop columns
df = df.drop([5]) # To drop rows
df
# Out:
#    Column1  Column2 Column3  Column5
# 0        1       78       A    False
# 1        2       94       C     True
# 2        3       59       B     True
# 3        4       32       C    False
# 4        5       65       B     True
# 6        7       21       A    False
# 7        8       74       D     True
# 8        9       37       D    False
# 9       10       27       A     True

# %%
df.columns  #give the names of the columns
# Out:
# Index(['Column1', 'Column2', 'Column3', 'Column5'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Column1  9 non-null      int64
#  1   Column2  9 non-null      int64
#  2   Column3  9 non-null      object
#  3   Column5  9 non-null      bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 297.0+ bytes

# %%
df.shape  #number of rows and columns
# Out:
# (10, 4)

# %%
df.describe()  #gives the statistical summary of the data
# Out:
#          Column1    Column2
# count   9.000000   9.000000
# mean    5.444444  54.111111
# std     3.205897  25.770353
# min     1.000000  21.000000
# 25%     3.000000  32.000000
# 50%     5.000000  59.000000
# 75%     8.000000  74.000000
# max    10.000000  94.000000

# %%
#2.Adding a new column:
names = [
    "Ekrishna", "Ram", "Nishan", "Sita", "Bibek", "Aarav", "Suman", "Sunita", "Kiran"
    ]
df["Names"]=names  # add a new column Names from the list named varibale names.
df
# df = df.drop(columns=['Ujjwal'])
df
# Out:
#    Column1  Column2 Column3  Column5     Names
# 0        1       78       A    False  Ekrishna
# 1        2       94       C     True       Ram
# 2        3       59       B     True    Nishan
# 3        4       32       C    False      Sita
# 4        5       65       B     True     Bibek
# 6        7       21       A    False     Aarav
# 7        8       74       D     True     Suman
# 8        9       37       D    False    Sunita
# 9       10       27       A     True     Kiran

# %%
# set the 'Name' column as index
df.set_index('Names', inplace=True)

print(df)
# Out:
#           Column1  Column2 Column3  Column5
# Names
# Ekrishna        1       78       A    False
# Ram             2       94       C     True
# Nishan          3       59       B     True
# Sita            4       32       C    False
# Bibek           5       65       B     True
# Aarav           7       21       A    False
# Suman           8       74       D     True
# Sunita          9       37       D    False
# Kiran          10       27       A     True

# %%
df
# Out:
#           Column1  Column2 Column3  Column5
# Names
# Ekrishna        1       78       A    False
# Ram             2       94       C     True
# Nishan          3       59       B     True
# Sita            4       32       C    False
# Bibek           5       65       B     True
# Aarav           7       21       A    False
# Suman           8       74       D     True
# Sunita          9       37       D    False
# Kiran          10       27       A     True

# %%
df.loc["Sita"]
df.loc["Sita":"Sunita"]
# Out:
#         Column1  Column2 Column3  Column5
# Names
# Sita          4       32       C    False
# Bibek         5       65       B     True
# Aarav         7       21       A    False
# Suman         8       74       D     True
# Sunita        9       37       D    False

# %%
df.iloc[3]
df.iloc[3:7]
# Out:
#        Column1  Column2 Column3  Column5
# Names
# Sita         4       32       C    False
# Bibek        5       65       B     True
# Aarav        7       21       A    False
# Suman        8       74       D     True

# %%
df.plot()
# Out:
# <Axes: xlabel='Names'>

# %% [markdown]
# .loc[] is used to access or modify rows and columns in a DataFrame by label (name) — not by position.

# %%
df.loc['Ram', 'Column1'] = 10    
df.loc['Puja', 'Column2'] = 50
df.loc['Puja', 'Column1'] = 9.5
df.loc['Puja', 'Column5'] = True
df.loc['Ujjwal', 'Column5'] = False # Adding new entries in the dataset
df.loc['ABC', 'Column5'] = True
print(df.loc["Ekrishna":"Sunita"])
print(df.iloc[0:5])
# print(df.loc["Ujjwal"]) # Accessing the newly added entries
df
# Out:
#           Column1  Column2 Column3 Column5
# Names
# Ekrishna      1.0     78.0       A   False
# Ram          10.0     94.0       C    True
# Nishan        3.0     59.0       B    True
# Sita          4.0     32.0       C   False
# Bibek         5.0     65.0       B    True
# Aarav         7.0     21.0       A   False
# Suman         8.0     74.0       D    True
# Sunita        9.0     37.0       D   False
#           Column1  Column2 Column3 Column5
# Names
# Ekrishna      1.0     78.0       A   False
# Ram          10.0     94.0       C    True
# Nishan        3.0     59.0       B    True
# Sita          4.0     32.0       C   False
# Bibek         5.0     65.0       B    True
#           Column1  Column2 Column3 Column5
# Names
# Ekrishna      1.0     78.0       A   False
# Ram          10.0     94.0       C    True
# Nishan        3.0     59.0       B    True
# Sita          4.0     32.0       C   False
# Bibek         5.0     65.0       B    True
# ...

# %%
df
# Out:
#           Column1  Column2 Column3 Column5
# Names
# Ekrishna      1.0     78.0       A   False
# Ram          10.0     94.0       C    True
# Nishan        3.0     59.0       B    True
# Sita          4.0     32.0       C   False
# Bibek         5.0     65.0       B    True
# Aarav         7.0     21.0       A   False
# Suman         8.0     74.0       D    True
# Sunita        9.0     37.0       D   False
# Kiran        10.0     27.0       A    True
# Puja          9.5     50.0     NaN    True
# Ujjwal        NaN      NaN     NaN   False
# ABC           NaN      NaN     NaN    True

# %%
df.loc["Ram","Column3"]="A"
df.loc["Ram"]
# Out:
# Column1    10.0
# Column2    94.0
# Column3       A
# Column5    True
# Name: Ram, dtype: object

# %%
df
# Out:
#           Column1  Column2 Column3 Column5
# Names
# Ekrishna      1.0     78.0       A   False
# Ram          10.0     94.0       A    True
# Nishan        3.0     59.0       B    True
# Sita          4.0     32.0       C   False
# Bibek         5.0     65.0       B    True
# Aarav         7.0     21.0       A   False
# Suman         8.0     74.0       D    True
# Sunita        9.0     37.0       D   False
# Kiran        10.0     27.0       A    True
# Puja          9.5     50.0     NaN    True
# Ujjwal        NaN      NaN     NaN   False
# ABC           NaN      NaN     NaN    True

# %%
df.loc["Ujjwal","Column1"]=11
df.loc["Ujjwal","Column2"]=33
df.loc["Ujjwal"]
# Out:
# Column1    11.0
# Column2    33.0
# Column3     NaN
# Column4     NaN
# Column5     NaN
# Name: Ujjwal, dtype: object

# %%
df
# Out:
#           Column1  Column2 Column3 Column5
# Names
# Ekrishna      1.0     78.0       A   False
# Ram          10.0     94.0       D    True
# Nishan        3.0     59.0       B    True
# Sita          4.0     32.0       C   False
# Bibek         5.0     65.0       B    True
# Aarav         7.0     21.0       A   False
# Suman         8.0     74.0       D    True
# Sunita        9.0     37.0       D   False
# Kiran        10.0     27.0       A    True
# Puja          9.5     50.0     NaN    True
# Ujjwal       11.0     33.0     NaN   False
# ABC           NaN      NaN     NaN    True

# %%
df.loc["Aarav":"Ujjwal"]
# Out:
#         Column1  Column2 Column3 Column5
# Names
# Aarav       7.0     21.0       A   False
# Suman       8.0     74.0       D    True
# Sunita      9.0     37.0       D   False
# Kiran      10.0     27.0       A    True
# Puja        9.5     50.0     NaN    True
# Ujjwal     11.0     33.0     NaN   False

# %%
df.iloc[5:9]
# Out:
#         Column1  Column2 Column3 Column5
# Names
# Aarav       7.0     21.0       A   False
# Suman       8.0     74.0       D    True
# Sunita      9.0     37.0       D   False
# Kiran      10.0     27.0       A    True

# %%
df.describe(include='all')
# Out:
#           Column1    Column2 Column3 Column5
# count   10.000000  10.000000       9      12
# unique        NaN        NaN       4       2
# top           NaN        NaN       A    True
# freq          NaN        NaN       4       7
# mean     6.650000  53.700000     NaN     NaN
# std      3.214982  24.331278     NaN     NaN
# min      1.000000  21.000000     NaN     NaN
# 25%      4.250000  33.250000     NaN     NaN
# 50%      7.500000  54.500000     NaN     NaN
# 75%      9.375000  71.750000     NaN     NaN
# max     10.000000  94.000000     NaN     NaN

# %%
df["Column1"]
# Out:
# Names
# Ekrishna     1.0
# Ram         10.0
# Nishan       3.0
# Sita         4.0
# Bibek        5.0
# Aarav        7.0
# Suman        8.0
# Sunita       9.0
# Kiran       10.0
# Puja         9.5
# Ujjwal       NaN
# ABC          NaN
# Name: Column1, dtype: float64

# %%
df[['Column1',"Column2","Column5"]]
# Out:
#           Column1  Column2 Column5
# Names
# Ekrishna      1.0     78.0   False
# Ram          10.0     94.0    True
# Nishan        3.0     59.0    True
# Sita          4.0     32.0   False
# Bibek         5.0     65.0    True
# Aarav         7.0     21.0   False
# Suman         8.0     74.0    True
# Sunita        9.0     37.0   False
# Kiran        10.0     27.0    True
# Puja          9.5     50.0    True
# Ujjwal        NaN      NaN   False
# ABC           NaN      NaN    True

# %%
total_column1 = df[['Column1','Column2']].sum()
print("Total values of total_column1:", total_column1)
average_column1 = df[['Column1','Column2']].mean()
print("Average total_column1:", average_column1)
median_column1 = df['Column1'].median()
print("Median:", median_column1)
mode = df['Column1'].mode()[0]
print("Mode of Column1 of Employees:", mode)
# Out:
# Total values of total_column1: Column1     77.5
# Column2    570.0
# dtype: float64
# Average total_column1: Column1     7.045455
# Column2    51.818182
# dtype: float64
# Median: 8.0
# Mode of Column1 of Employees: 10.0

# %% [markdown]
# | Use Case      | Use `.loc[]` when...                | Use `.iloc[]` when...                        |
# | ------------- | ----------------------------------- | -------------------------------------------- |
# | Column access | You know column names               | You know column positions                    |
# | Indexing rows | You use custom labels (e.g., names) | You want rows by number (e.g., first 5 rows) |

# %%
print(df.iloc[1]) # Selects the row at index position 1
print(df.iloc[1:3]) # Selects rows 1 and 2 (Python slicing is end-exclusive).
print(df.iloc[1:3,0:2]) # Selects rows 1 and 2 AND columns 0 and 1 (again, slice is end-exclusive)
# Out:
# Column1    10.0
# Column2    94.0
# Column3       D
# Column5    True
# Name: Ram, dtype: object
#         Column1  Column2 Column3 Column5
# Names
# Ram        10.0     94.0       D    True
# Nishan      3.0     59.0       B    True
#         Column1  Column2
# Names
# Ram        10.0     94.0
# Nishan      3.0     59.0

# %%
#checking null values
df.isnull().sum()
# Out:
# Column1    0
# Column2    0
# Column3    1
# Column4    1
# Column5    1
# dtype: int64

# %%
df
# Out:
#           Column1  Column2 Column3 Column5
# Names
# Ekrishna      1.0     78.0       A   False
# Ram          10.0     94.0       A    True
# Nishan        3.0     59.0       B    True
# Sita          4.0     32.0       C   False
# Bibek         5.0     65.0       B    True
# Aarav         7.0     21.0       A   False
# Suman         8.0     74.0       D    True
# Sunita        9.0     37.0       D   False
# Kiran        10.0     27.0       A    True
# Puja          9.5     50.0     NaN    True
# Ujjwal        NaN      NaN     NaN   False
# ABC           NaN      NaN     NaN    True

# %%
df.shape
# Out:
# (11, 5)

# %%
df = df.fillna(0)

# %%
df.shape
# Out:
# (11, 5)

# %%
df.isnull().sum()
# Out:
# Column1    0
# Column2    0
# Column3    0
# Column4    0
# Column5    0
# dtype: int64

# %%
df
# Out:
#         Column1  Column2 Column3  Column4 Column5
# 0           1.0     78.0       A    -0.61   False
# 1           2.0     94.0       C    -0.90    True
# 2           3.0     59.0       B    -0.17    True
# 3           4.0     32.0       C    -2.74   False
# 4           5.0     65.0       B     1.14    True
# 5           6.0     94.0       D    -0.76    True
# 6           7.0     21.0       A    -1.48   False
# 7           8.0     74.0       D    -0.37    True
# 8           9.0     37.0       D     1.00   False
# 9          10.0     27.0       A    -0.27    True
# Ujjwal     11.0     33.0       0     0.00       0

# %%
df.shape
# Out:
# (12, 1)

# %% [markdown]
# -----------------------------------Pandas Pivot-------------------
# =========================The pivot() function in Pandas reshapes data based on column values. It takes simple column-wise data as input, and groups the entries into a two-dimensional table.
#
# ===============================================================
# ![alt text](image.png)

# %% [markdown]
# ---------------------------------------------------------
#
# a Pivot is used to reshape data — it transforms unique values from one column into new columns, and uses another column’s values to fill in the cells.
#
# Syntax:
# df.pivot(index='row_column', columns='column_column', values='values_column')
#
# Pivot Table
#
# Can handle duplicates by applying an aggregation function (mean, sum, etc.)
#
# Syntax:
# pd.pivot_table(data, index="", columns="", values="", aggfunc="")

# %% [markdown]
# pivot_df = pd.pivot_table(
#
# )
#
# print(pivot_df)

# %%
df
# Out:
#          Column5
# Names
# Ekrishna   False
# Ram         True
# Nishan      True
# Sita       False
# Bibek       True
# Aarav      False
# Suman       True
# Sunita     False
# Kiran       True
# Puja        True
# Ujjwal     False
# ABC         True

# %%
df2 = pd.read_csv("sampledata.csv")
df2
# Out:
#    Column1  Column2 Column3  Column4  Column5
# 0        1       78       A    -0.61    False
# 1        2       94       C    -0.90     True
# 2        3       59       B    -0.17     True
# 3        4       32       C    -2.74    False
# 4        5       65       B     1.14     True
# 5        6       94       D    -0.76     True
# 6        7       21       A    -1.48    False
# 7        8       74       D    -0.37     True
# 8        9       37       D     1.00    False
# 9       10       27       A    -0.27     True

# %%
df
# Out:
#          Column5
# Names
# Ekrishna   False
# Ram         True
# Nishan      True
# Sita       False
# Bibek       True
# Aarav      False
# Suman       True
# Sunita     False
# Kiran       True
# Puja        True
# Ujjwal     False
# ABC         True

# %%
df2 = df2.drop([4,5,6,7,8,9])
df2
# Out:
#    Column1  Column2 Column3  Column4  Column5
# 0        1       78       A    -0.61    False
# 1        2       94       C    -0.90     True
# 2        3       59       B    -0.17     True
# 3        4       32       C    -2.74    False

# %%
# Update Ram's Column2
df.loc['Ram', 'Column2'] = 100

# Recreate the pivot table after update
df_pivot = pd.pivot_table(
    data=df,
    index='Names',
    values='Column2',
    aggfunc='sum'
)

print(df_pivot.loc["Ram"])  # Should now show 100000
# Out:
# Column2    100.0
# Name: Ram, dtype: float64
# C:\Users\acer\AppData\Local\Temp\ipykernel_23852\3916101800.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc['Ram', 'Column2'] = 100

# %% [markdown]
# | Function        | What it does                                                                         |
# | --------------- | ------------------------------------------------------------------------------------ |
# | `pivot()`       | Just reshapes data; must be unique for index+columns; no aggregation                 |
# | `pivot_table()` | Reshapes data **and** can aggregate duplicates using `aggfunc` (`sum`, `mean`, etc.) |

# %% [markdown]
# ============================= DataFrame.dropna() function
#
# this is a dropna() functions:
# ---------------DataFrame.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
#
#
#
# axis: It determines the axis to remove. Set it to 1 or column to remove columns containing missing values. By default, it removes rows with NA from DataFrame.
# how: It takes the following inputs:
# ‘any’: This is the default case to drop the column if it has at least one value missing.
# ‘all’: Drop the column only if it has all the values as NA.
# thresh: It applies a condition to drop the columns only if it does not contain the required number of values. It takes an int as input.
# subset: While dropping columns, it is used to specify the list of rows to be considered to find NA.
# inplace: It is used to specify whether to return a new DataFrame or update an existing one. It is a boolean flag with default False.

# %% [markdown]
# ![alt text](image-1.png)

# %%
import numpy as np
data = {
    "Name": ["Joe","Sam","Harry"],
    "Age":[20,np.nan,19],
    "Marks":[85.10, 95.65, np.nan]
} 
df = pd.DataFrame(data)
df
# Out:
#     Name   Age  Marks
# 0    Joe  20.0  85.10
# 1    Sam   NaN  95.65
# 2  Harry  19.0    NaN

# %%
df.dropna(how="all", subset="Age")
# Out:
#   Name   Age  Marks
# 0  Joe  20.0  85.10
# 1  Sam   NaN  95.65

# %%
import pandas as pd
df_nan = pd.read_csv("dropna_nan.csv")
df_nan
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  30.0    NaN
# 3    David   NaN   75.0
# 4      Eve  22.0   88.0

# %%
df_nan[['Age','Name','Score']]
# Out:
#     Age     Name  Score
# 0  25.0    Alice   85.0
# 1   NaN      Bob   90.0
# 2  30.0  Charlie    NaN
# 3   NaN    David   75.0
# 4  22.0      Eve   88.0

# %%
df_nan['Score'].fillna(df_nan['Score'].mean())
# Out:
# 0    85.0
# 1    90.0
# 2    84.5
# 3    75.0
# 4    88.0
# Name: Score, dtype: float64

# %%
df_clean = pd.DataFrame(df_nan['Age'].fillna(20))
df_clean
# Out:
#     Age
# 0  25.0
# 1  20.0
# 2  30.0
# 3  20.0
# 4  22.0

# %%
df_nan2 = df_nan['Score'].fillna(df_nan['Score'].mean())

# %%
df_nan2
# Out:
# 0    85.0
# 1    90.0
# 2    84.5
# 3    75.0
# 4    88.0
# Name: Score, dtype: float64

# %%
df_nan['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# Name: Name, dtype: object

# %%
df_clean = pd.DataFrame(df_nan['Age'].fillna(20))
df_concat = pd.merge(df_clean, df_nan['Score'].fillna(df_nan['Score'].mean()), how='right', on=df_nan['Name'])
print(df_concat)
# Out:
#      key_0   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob  20.0   90.0
# 2  Charlie  30.0   84.5
# 3    David  20.0   75.0
# 4      Eve  22.0   88.0

# %%
df_clean
# Out:
#     Age
# 0  25.0
# 1  20.0
# 2  30.0
# 3  20.0
# 4  22.0

# %%
df_nan
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  30.0    NaN
# 3    David   NaN   75.0
# 4      Eve  22.0   88.0

# %%
df_clean = df_nan.dropna(axis=1)
df_clean
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    David
# 4      Eve

# %%
df_nan
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  30.0    NaN
# 3    David   NaN   75.0
# 4      Eve  22.0   88.0

# %%
# df_age_clean = df_nan.dropna(axis=0)
# df_age_clean

# %%
df_nan
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  30.0    NaN
# 3    David   NaN   75.0
# 4      Eve  22.0   88.0

# %%
df_nan
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  30.0    NaN
# 3    David   NaN   75.0
# 4      Eve  22.0   88.0

# %%
import numpy as np
# df_rep = df_nan.replace(np.nan, 25.0)
df_rep = df_nan.replace(22.0, 25.0)
df_rep
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  30.0    NaN
# 3    David   NaN   75.0
# 4      Eve  25.0   88.0

# %%
df_rep = df_rep.replace(0, 15)
df_rep
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  30.0    NaN
# 3    David   NaN   75.0
# 4      Eve  25.0   88.0

# %%
# df_age_clean = df_age_clean.fillna(df_age_clean["Age"].mean())
# df_age_clean

# %% [markdown]
# | Parameter   | Description                                                                                                                                                          | Example / Notes                                                                                                                  |
# | ----------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------- |
# | **axis**    | Determines if you drop **rows** or **columns** with missing values. `0` = rows, `1` = columns                                                                        | `df.dropna(axis=0)` → drop rows with NaN<br>`df.dropna(axis=1)` → drop columns with NaN                                          |
# | **how**     | Determines if a row/column is dropped **when it has any or all NaNs**. Options:<br>`any` → drop if **any NaN** exists<br>`all` → drop only if **all values are NaN** | `df.dropna(how='any')` → default, drops rows with any missing value<br>`df.dropna(how='all')` → only drops rows completely empty |
# | **thresh**  | Minimum number of **non-NaN values required to keep** the row/column                                                                                                 | `df.dropna(thresh=2)` → keep rows with **at least 2 non-NaN values**                                                             |
# | **subset**  | Only consider certain columns for checking NaN                                                                                                                       | `df.dropna(subset=['Age', 'Score'])` → only check these columns                                                                  |
# | **inplace** | If `True`, modifies the original DataFrame. If `False` (default), returns a new DataFrame                                                                            | `df.dropna(inplace=True)` → original `df` is updated<br>`df_clean = df.dropna()` → creates new cleaned df                        |

# %%
import pandas as pd
data = {
    "Name": ["Alice", "Bob", "Charlie","Alice", "Bob", "Charlie","Alice","Bob","Charlie", "Alice"],
    "Subjects": ["Math", "Math", "Math","Science", "Science", "Science","English","English","English", "Math"],
    "Scores": [85, 90, 78, 88, 92, 80, 97, 86, 89,96]
}
df = pd.DataFrame(data)
df
# Out:
#       Name Subjects  Scores
# 0    Alice     Math      85
# 1      Bob     Math      90
# 2  Charlie     Math      78
# 3    Alice  Science      88
# 4      Bob  Science      92
# 5  Charlie  Science      80
# 6    Alice  English      97
# 7      Bob  English      86
# 8  Charlie  English      89
# 9    Alice     Math      96

# %%
# Pivot cannot handle duplicate values for same index and same column
df.pivot(index="Name", columns="Subjects", values="Scores")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Pivot cannot handle duplicate values for same index and same column
# ----> 2 df.pivot(index="Name", columns="Subjects", values="Scores")
#
# File c:\Users\acer\anaconda3\Lib\site-packages\pandas\core\frame.py:9366, in DataFrame.pivot(self, columns, index, values)
#    9359 @Substitution("")
#    9360 @Appender(_shared_docs["pivot"])
#    9361 def pivot(
#    9362     self, *, columns, index=lib.no_default, values=lib.no_default
#    9363 ) -> DataFrame:
#    9364     from pandas.core.reshape.pivot import pivot
# -> 9366     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\Users\acer\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:570, in pivot(data, columns, index, values)
# ...

# %%
df
# Out:
#       Name Subjects  Scores
# 0    Alice     Math      85
# 1      Bob     Math      90
# 2  Charlie     Math      78
# 3    Alice  Science      88
# 4      Bob  Science      92
# 5  Charlie  Science      80
# 6    Alice  English      97
# 7      Bob  English      86
# 8  Charlie  English      89
# 9    Alice     Math      96

# %%
# Since pivot cannot handle duplicates, 
# We need to use pivot_table for handling the duplicates
df.pivot_table(index="Name", columns="Subjects", values="Scores", aggfunc='mean')
# Out:
# Subjects  English  Math  Science
# Name
# Alice        97.0  90.5     88.0
# Bob          86.0  90.0     92.0
# Charlie      89.0  78.0     80.0

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
import pandas as pd

students = {
    "id" : [1,2,3,4,5,6],
    "Name": ["Alice", "Bob", "Charlie","David", "Eva", "Frank"],
    "Age": [20, 21, 19, 22, 20, 23],
}

marks = {
    "id" : [1,2,3,4,5,6],
    # "student_id": [1,2,3,10,11,12],
    "Name": ["Alice", "Bob", "Charlie","Ujjwal", "Ram", "Sita"],
    "Math": [85, 90, 78, 88, 92, 80],
    "Science": [88, 92, 80, 85, 87, 90],
    "English": [97, 86, 89, 91, 93, 88]
}

students = pd.DataFrame(students)
marks = pd.DataFrame(marks)
print(students)
print(marks)
print()
print()

merged = pd.merge(students, marks, on="Name", how="outer")
# # merged = pd.merge(students, marks, , how="outer")
print(merged)
# Out:
#    id     Name  Age
# 0   1    Alice   20
# 1   2      Bob   21
# 2   3  Charlie   19
# 3   4    David   22
# 4   5      Eva   20
# 5   6    Frank   23
#    id     Name  Math  Science  English
# 0   1    Alice    85       88       97
# 1   2      Bob    90       92       86
# 2   3  Charlie    78       80       89
# 3   4   Ujjwal    88       85       91
# 4   5      Ram    92       87       93
# 5   6     Sita    80       90       88
#
#
#    id_x     Name   Age  id_y  Math  Science  English
# 0   1.0    Alice  20.0   1.0  85.0     88.0     97.0
# 1   2.0      Bob  21.0   2.0  90.0     92.0     86.0
# 2   3.0  Charlie  19.0   3.0  78.0     80.0     89.0
# 3   4.0    David  22.0   NaN   NaN      NaN      NaN
# 4   5.0      Eva  20.0   NaN   NaN      NaN      NaN
# 5   6.0    Frank  23.0   NaN   NaN      NaN      NaN
# 6   NaN      Ram   NaN   5.0  92.0     87.0     93.0
# 7   NaN     Sita   NaN   6.0  80.0     90.0     88.0
# 8   NaN   Ujjwal   NaN   4.0  88.0     85.0     91.0

# %%
concatenated = pd.concat([students, marks], axis=1)
print(concatenated)
# Out:
#    id     Name  Age  id     Name  Math  Science  English
# 0   1    Alice   20   1    Alice    85       88       97
# 1   2      Bob   21   2      Bob    90       92       86
# 2   3  Charlie   19   3  Charlie    78       80       89
# 3   4    David   22   4   Ujjwal    88       85       91
# 4   5      Eva   20   5      Ram    92       87       93
# 5   6    Frank   23   6     Sita    80       90       88
